# %%
#BY mmohammad tabrez

# %%
#importing libarares 
import pandas as pd 
import numpy as np

# %%
#Reading Excel Data file 
bsed = pd.read_excel('bse.xls')
bsed
# Out:
#                                 Company       Sector               Industry  \
# 0                         3M India Ltd.     Services                Trading
# 1                 Aarti Industries Ltd.    Chemicals      Organic Chemicals
# 2                 Aavas Financiers Ltd.    Financial        Housing Finance
# 3                              ABB Ltd.  Engineering    Switching Equipment
# 4                     Abbott India Ltd.   Healthcare         Drugs & Pharma
# ..                                  ...          ...                    ...
# 496                          Wipro Ltd.   Technology      Computer Software
# 497                      Wockhardt Ltd.   Healthcare         Drugs & Pharma
# 498  Zee Entertainment Enterprises Ltd.     Services  Media & Entertainment
# 499            Zensar Technologies Ltd.   Technology      Computer Hardware
# 500                 Zydus Wellness Ltd.         FMCG        Food Processing
#
#         Price  Dividend Per Share
# ...

# %%
#setting index as company
seenbse=bsed.set_index('Company')
nbse
# Out:
#                                          Sector               Industry  \
# Company
# 3M India Ltd.                          Services                Trading
# Aarti Industries Ltd.                 Chemicals      Organic Chemicals
# Aavas Financiers Ltd.                 Financial        Housing Finance
# ABB Ltd.                            Engineering    Switching Equipment
# Abbott India Ltd.                    Healthcare         Drugs & Pharma
# ...                                         ...                    ...
# Wipro Ltd.                           Technology      Computer Software
# Wockhardt Ltd.                       Healthcare         Drugs & Pharma
# Zee Entertainment Enterprises Ltd.     Services  Media & Entertainment
# Zensar Technologies Ltd.             Technology      Computer Hardware
# Zydus Wellness Ltd.                        FMCG        Food Processing
#
#                                        Price  Dividend Per Share
# Company
# ...

# %%
#see no of companies
nocompanies = len(nbse)
nocompanies
# Out:
# 501

# %%
#renaming Dividend Per Share
bse=nbse.rename(columns={'Dividend Per Share':'DividendPerShare'})
bse
# Out:
#                                          Sector               Industry  \
# Company
# 3M India Ltd.                          Services                Trading
# Aarti Industries Ltd.                 Chemicals      Organic Chemicals
# Aavas Financiers Ltd.                 Financial        Housing Finance
# ABB Ltd.                            Engineering    Switching Equipment
# Abbott India Ltd.                    Healthcare         Drugs & Pharma
# ...                                         ...                    ...
# Wipro Ltd.                           Technology      Computer Software
# Wockhardt Ltd.                       Healthcare         Drugs & Pharma
# Zee Entertainment Enterprises Ltd.     Services  Media & Entertainment
# Zensar Technologies Ltd.             Technology      Computer Hardware
# Zydus Wellness Ltd.                        FMCG        Food Processing
#
#                                        Price  DividendPerShare
# Company
# ...

# %%
#getting Dividend Cos where D >= 20 per share 
dv=bse[bse.DividendPerShare >= 20 ]
dv
# Out:
#                                                    Sector  \
# Company
# Abbott India Ltd.                              Healthcare
# Akzo Nobel India Ltd.                           Chemicals
# Alkem Laboratories Ltd.                        Healthcare
# Alkyl Amines Chemicals Ltd.                     Chemicals
# Atul Ltd.                                       Chemicals
# Bajaj Auto Ltd                                 Automobile
# Bajaj Holdings & Investment Ltd.                Financial
# Balkrishna Industries Ltd.                     Automobile
# Bayer CropScience Ltd.                         Healthcare
# Bosch Ltd.                                     Automobile
# Britannia Industries Ltd.                            FMCG
# CARE Ratings Ltd.                               Financial
# CESC Ltd.                                          Energy
# Colgate-Palmolive (India) Ltd.                       FMCG
# Crisil Ltd.                                     Financial
# ...

# %%
#No of companies where D is >= 20 per share
noc=len(dv)
noc
# Out:
# 55

# %%
#getting health sector stocks where D is >= 20 per share Dividend
hc = dv.loc[dv['Sector'] == 'Healthcare']
hc
# Out:
#                                           Sector         Industry     Price  \
# Company
# Abbott India Ltd.                     Healthcare   Drugs & Pharma  14903.90
# Alkem Laboratories Ltd.               Healthcare   Drugs & Pharma   2476.45
# Bayer CropScience Ltd.                Healthcare   Drugs & Pharma   5781.20
# Dr. Reddy's Laboratories Ltd.         Healthcare   Drugs & Pharma   4118.45
# Glaxosmithkline Pharmaceuticals Ltd.  Healthcare   Drugs & Pharma   1480.00
# Pfizer Ltd.                           Healthcare   Drugs & Pharma   4331.00
# Procter & Gamble Health Ltd.          Healthcare   Drugs & Pharma   4197.50
# Sanofi India Ltd.                     Healthcare   Drugs & Pharma   7865.00
# Thyrocare Technologies Ltd.           Healthcare  Health Services    702.35
# Torrent Pharmaceuticals Ltd.          Healthcare   Drugs & Pharma   2349.20
#
#                                       DividendPerShare
# Company
# Abbott India Ltd.                                 65.0
# ...

# %%
#no of comapnies 
noh=len(hc)
noh
# Out:
# 10

# %%
#getting Chemicals stocks where is d >= 20 per share Dividend
ch = dv.loc[dv['Sector'] == 'Chemicals']
ch
# Out:
#                                 Sector            Industry   Price  \
# Company
# Akzo Nobel India Ltd.        Chemicals  Paints & Varnishes  1864.8
# Alkyl Amines Chemicals Ltd.  Chemicals   Organic Chemicals  2282.2
# Atul Ltd.                    Chemicals     Dyes & Pigments  5119.0
#
#                              DividendPerShare
# Company
# Akzo Nobel India Ltd.                    24.0
# Alkyl Amines Chemicals Ltd.              20.0
# Atul Ltd.                                27.5

# %%
#no of comapnies 
noC=len(ch)
noC
# Out:
# 3

# %%
#getting Automobile stocks where d is >= 20 per share Dividend
Au = dv.loc[dv['Sector'] == 'Automobile']
Au
# Out:
#                                 Sector                       Industry  \
# Company
# Bajaj Auto Ltd              Automobile           Two & Three Wheelers
# Balkrishna Industries Ltd.  Automobile                  Tyres & Tubes
# Bosch Ltd.                  Automobile               Auto Ancillaries
# Eicher Motors Ltd.          Automobile           Two & Three Wheelers
# Hero Motocorp Ltd.          Automobile           Two & Three Wheelers
# Maharashtra Scooters Ltd.   Automobile           Two & Three Wheelers
# Maruti Suzuki India Ltd.    Automobile  Cars & Multi Utility Vehicles
# MRF Ltd.                    Automobile                  Tyres & Tubes
# TVS Srichakra Ltd.          Automobile                  Tyres & Tubes
#
#                                Price  DividendPerShare
# Company
# Bajaj Auto Ltd               3116.15             120.0
# Balkrishna Industries Ltd.   1251.35              20.0
# Bosch Ltd.                  13249.95             105.0
# ...

# %%
#no of comapnies 
noA=len(Au)
noA
# Out:
# 9

# %%
#getting Financial stocks where d is >= 20 per share Dividend
Fi = dv.loc[dv['Sector'] == 'Financial']
Fi
# Out:
#                                             Sector  \
# Company
# Bajaj Holdings & Investment Ltd.         Financial
# CARE Ratings Ltd.                        Financial
# Crisil Ltd.                              Financial
# Housing Development Finance Corpn. Ltd.  Financial
# Indiabulls Housing Finance Ltd.          Financial
# Multi Commodity Exchange India           Financial
#
#                                                              Industry  \
# Company
# Bajaj Holdings & Investment Ltd.                      Invest.Services
# CARE Ratings Ltd.                        Credit Ratings & Information
# Crisil Ltd.                              Credit Ratings & Information
# Housing Development Finance Corpn. Ltd.               Housing Finance
# Indiabulls Housing Finance Ltd.                       Housing Finance
# Multi Commodity Exchange India                     Misc. Fin.services
#
#                                            Price  DividendPerShare
# Company
# ...

# %%
#no of comapnies 
noF=len(Fi)
noF
# Out:
# 6

# %%
#getting FMCG stocks whered is >= 20 per share Dividend
Fm = dv.loc[dv['Sector'] == 'FMCG']
Fm
# Out:
#                                             Sector                Industry  \
# Company
# Britannia Industries Ltd.                     FMCG  Bakery & Milling Prod.
# Colgate-Palmolive (India) Ltd.                FMCG  Cosmetics & Toiletries
# Gillette India Ltd.                           FMCG  Cosmetics & Toiletries
# Hindustan Unilever Ltd.                       FMCG  Cosmetics & Toiletries
# Nestle India Ltd.                             FMCG          Dairy products
# Procter & Gamble Hygiene & Health Care Ltd.   FMCG  Cosmetics & Toiletries
# VST Industries Ltd.                           FMCG           Tobacco Prod.
#
#                                                 Price  DividendPerShare
# Company
# Britannia Industries Ltd.                     3807.10              35.0
# Colgate-Palmolive (India) Ltd.                1437.50              28.0
# Gillette India Ltd.                           5080.90              44.0
# ...

# %%
#no of comapnies 
noFM=len(Fm)
noFM
# Out:
# 7

# %%
#getting FMCG stocks where d is >= 20 per share Dividend
Me = dv.loc[dv['Sector'] == 'Metals']
Me
# Out:
#                      Sector                 Industry   Price  DividendPerShare
# Company
# Hindustan Zinc Ltd.  Metals  Other Non-Ferrous Metal  207.35              20.0

# %%
#no of comapnies 
noM=len(Me)
noM
# Out:
# 1

# %%
#getting FMCG stocks which is >= 20 per share Dividend
En = dv.loc[dv['Sector'] == 'Energy']
En
# Out:
#                     Sector                 Industry   Price  DividendPerShare
# Company
# CESC Ltd.           Energy   Electricity Generation   564.6              20.0
# Mahanagar Gas Ltd.  Energy  Crude Oil & Natural Gas  1009.7              20.0

# %%
#no of comapnies 
noE=len(En)
noE
# Out:
# 2

# %%
#getting FMCG stocks where d is >= 20 per share Dividend
Te = dv.loc[dv['Sector'] == 'Technology']
Te
# Out:
#                                              Sector           Industry  \
# Company
# Larsen & Toubro Infotech Ltd.            Technology  Computer Software
# Mphasis Ltd.                             Technology  Computer Software
# NIIT Technologies Ltd.                   Technology  Computer Software
# Oracle Financial Services Software Ltd.  Technology  Computer Software
# Sonata Software Ltd.                     Technology  Computer Software
# Tata Consultancy Services Ltd.           Technology  Computer Software
#
#                                            Price  DividendPerShare
# Company
# Larsen & Toubro Infotech Ltd.            2419.00             28.00
# Mphasis Ltd.                             1163.70             35.00
# NIIT Technologies Ltd.                   1856.20             31.00
# Oracle Financial Services Software Ltd.  2990.00            180.00
# Sonata Software Ltd.                      259.00             20.25
# ...

# %%
#no of comapnies 
noT=len(Te)
noT
# Out:
# 6

# %%
#getting FMCG stocks where is d >= 20 per share Dividend
Tx = dv.loc[dv['Sector'] == 'Textiles']
Tx
# Out:
#                         Sector Industry    Price  DividendPerShare
# Company
# Page Industries Ltd.  Textiles    Cloth  19225.5             161.0

# %%
#no of comapnies 
noTx=len(Tx)
noTx
# Out:
# 1

# %%
#getting FMCG stocks where d is >= 20 per share Dividend
En = dv.loc[dv['Sector'] == 'Engineering']
En
# Out:
#                                       Sector              Industry     Price  \
# Company
# Esab India Ltd.                  Engineering     Welding machinery   1416.05
# HEG Ltd.                         Engineering     Welding machinery    777.05
# Honeywell Automation India Ltd.  Engineering   Electronic Equipts.  27350.00
# L&T Technology Services Ltd.     Engineering        Other Projects   1507.00
# Schaeffler India Ltd.            Engineering         Ball Bearings   3643.00
# SKF India Ltd.                   Engineering         Ball Bearings   1462.70
# Timken India Ltd.                Engineering  Industrial Machinery    976.25
#
#                                  DividendPerShare
# Company
# Esab India Ltd.                              90.0
# HEG Ltd.                                     80.0
# Honeywell Automation India Ltd.              75.0
# L&T Technology Services Ltd.                 21.0
# Schaeffler India Ltd.                        35.0
# ...

# %%
#no of comapnies 
noEn=len(En)
noEn
# Out:
# 7

# %%
#getting FMCG stocks where d is >= 20 per share Dividend
Co = dv.loc[dv['Sector'] == 'Cons Durable']
Co
# Out:
#                            Sector                     Industry   Price  \
# Company
# TTK Prestige Ltd.    Cons Durable  Domestic Electrical Applns.  5488.0
# Vaibhav Global Ltd.  Cons Durable             Gems & Jewellery  1335.0
#
#                      DividendPerShare
# Company
# TTK Prestige Ltd.               30.00
# Vaibhav Global Ltd.             33.74

# %%
#no of comapnies 
noCo=len(Co)
noCo
# Out:
# 2

# %%
#getting Construction stocks where d is >= 20 per share Dividend
cn = dv.loc[dv['Sector'] == 'Construction']
cn
# Out:
#                          Sector Industry    Price  DividendPerShare
# Company
# Shree Cement Ltd.  Construction   Cement  22001.9             110.0

# %%
#no of comapnies
nocn=len(cn)
nocn
# Out:
# 1

# %%
#The end
